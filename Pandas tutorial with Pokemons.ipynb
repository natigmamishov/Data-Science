# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import missingno as msn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Extract Dataset

# %%
df=pd.read_csv(r"datasets/Pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(7)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.tail(7)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ##### Cleaning the dataframe

# %%
df['Name']=df.Name.str.replace(".*(?=Mega)", "")
# Out:
# <ipython-input-9-70918329da13>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name']=df.Name.str.replace(".*(?=Mega)", "")

# %%
df.rename(columns={'#':'Number'}, inplace=True)

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Number      800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape
# Out:
# (800, 13)

# %%
print('The columns of the dataset are:', df.columns) #show the dataframe columns
print('The shape of the dataframe is:', df.shape)    #shape of the dataframe
# Out:
# The columns of the dataset are: Index(['Number', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# The shape of the dataframe is: (800, 13)

# %%
print('The unique  pokemon types are', df['Type 1'].unique()) #shows all the unique types in column
print('The number of unique types are', df['Type 1'].nunique()) #shows count of unique values
# Out:
# The unique  pokemon types are ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
# The number of unique types are 18

# %%
df.nunique()
# Out:
# Number        721
# Name          800
# Type 1         18
# Type 2         18
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %% [markdown]
# ##### Missing Values

# %%
df.isnull().sum()
# Out:
# Number          0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Number        0.0000
# Name          0.0000
# Type 1        0.0000
# Type 2        0.4825
# Total         0.0000
# HP            0.0000
# Attack        0.0000
# Defense       0.0000
# Sp. Atk       0.0000
# Sp. Def       0.0000
# Speed         0.0000
# Generation    0.0000
# Legendary     0.0000
# dtype: float64

# %%
msn.matrix(df)
plt.show()

# %%
msn.bar(df)
plt.show()

# %%
df['Type 2'].mode()
# Out:
# 0    Flying
# dtype: object

# %%
df['Type 2'].mode()[0]
# Out:
# 'Flying'

# %%
df.dropna()
#df.dropna(inplace=True)
# Out:
#      Number                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1            Bulbasaur    Grass  Poison    318  45      49       49
# 1         2              Ivysaur    Grass  Poison    405  60      62       63
# 2         3             Venusaur    Grass  Poison    525  80      82       83
# 3         3        Mega Venusaur    Grass  Poison    625  80     100      123
# 6         6            Charizard     Fire  Flying    534  78      84       78
# ..      ...                  ...      ...     ...    ...  ..     ...      ...
# 795     719              Diancie     Rock   Fairy    600  50     100      150
# 796     719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797     720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799     721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Number        0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df['Type 2'].fillna(df['Type 2'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Number        0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# Number      800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %%
df.describe(include=['object']).T
# Out:
#        count unique       top freq
# Name     800    800  Staravia    1
# Type 1   800     18     Water  112
# Type 2   800     18    Flying  483

# %%
df['Legendary']=df['Legendary'].astype(int)

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.Name
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3            Mega Venusaur
# 4               Charmander
#               ...
# 795                Diancie
# 796           Mega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Type 1', 'Type 2']]
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1      Grass  Poison
# 2      Grass  Poison
# 3      Grass  Poison
# 4       Fire  Flying
# ..       ...     ...
# 795     Rock   Fairy
# 796     Rock   Fairy
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [800 rows x 2 columns]

# %%
df['HP']>80
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: HP, Length: 800, dtype: bool

# %%
df[df['HP']>80]
# Out:
#      Number              Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 22       18           Pidgeot  Normal  Flying    479   83      80       75
# 23       18      Mega Pidgeot  Normal  Flying    579   83      80       80
# 36       31         Nidoqueen  Poison  Ground    505   90      92       87
# 39       34          Nidoking  Poison  Ground    505   81     102       77
# 41       36          Clefable   Fairy  Flying    483   95      70       73
# ..      ...               ...     ...     ...    ...  ...     ...      ...
# 789     713           Avalugg     Ice  Flying    514   95     117      184
# 791     715           Noivern  Flying  Dragon    535   85      70       80
# 792     716           Xerneas   Fairy  Flying    680  126     131       95
# 793     717           Yveltal    Dark  Flying    680  126     131       95
# 794     718  Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df['HP']>80]['HP']
# Out:
# 22      83
# 23      83
# 36      90
# 39      81
# 41      95
#       ...
# 789     95
# 791     85
# 792    126
# 793    126
# 794    108
# Name: HP, Length: 193, dtype: int64

# %%
df[df['HP']>80][['HP', 'Type 1']]
# Out:
#       HP  Type 1
# 22    83  Normal
# 23    83  Normal
# 36    90  Poison
# 39    81  Poison
# 41    95   Fairy
# ..   ...     ...
# 789   95     Ice
# 791   85  Flying
# 792  126   Fairy
# 793  126    Dark
# 794  108  Dragon
#
# [193 rows x 2 columns]

# %%
df[(df['HP']>80) & (df['Type 1']=='Water') ]
# Out:
#      Number                  Name Type 1    Type 2  Total   HP  Attack  \
# 67       62             Poliwrath  Water  Fighting    510   90      95
# 85       79              Slowpoke  Water   Psychic    315   90      65
# 86       80               Slowbro  Water   Psychic    490   95      75
# 87       80          Mega Slowbro  Water   Psychic    590   95      75
# 94       87               Dewgong  Water       Ice    475   90      70
# 140     130              Gyarados  Water    Flying    540   95     125
# 141     130         Mega Gyarados  Water      Dark    640   95     155
# 142     131                Lapras  Water       Ice    535  130      85
# 145     134              Vaporeon  Water    Flying    525  130      65
# 174     160            Feraligatr  Water    Flying    530   85     105
# 185     171               Lanturn  Water  Electric    460  125      58
# 199     184             Azumarill  Water     Fairy    420  100      50
# ...

# %%
df[(df['HP']>80) | (df['Type 1']=='Water') ]
# Out:
#      Number              Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 9         7          Squirtle   Water  Flying    314   44      48       65
# 10        8         Wartortle   Water  Flying    405   59      63       80
# 11        9         Blastoise   Water  Flying    530   79      83      100
# 12        9    Mega Blastoise   Water  Flying    630   79     103      120
# 22       18           Pidgeot  Normal  Flying    479   83      80       75
# ..      ...               ...     ...     ...    ...  ...     ...      ...
# 789     713           Avalugg     Ice  Flying    514   95     117      184
# 791     715           Noivern  Flying  Dragon    535   85      70       80
# 792     716           Xerneas   Fairy  Flying    680  126     131       95
# 793     717           Yveltal    Dark  Flying    680  126     131       95
# 794     718  Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['HP']>80) & (df['Type 1']=='Water') ][['HP', 'Type 1']]
# Out:
#       HP Type 1
# 67    90  Water
# 85    90  Water
# 86    95  Water
# 87    95  Water
# 94    90  Water
# 140   95  Water
# 141   95  Water
# 142  130  Water
# 145  130  Water
# 174   85  Water
# 185  125  Water
# 199  100  Water
# 201   90  Water
# 210   95  Water
# 214   95  Water
# 264  100  Water
# 282  100  Water
# 283  100  Water
# 350  130  Water
# 351  170  Water
# 372  110  Water
# 382   95  Water
# 404  100  Water
# 421  100  Water
# 422  100  Water
# 440   84  Water
# 466   85  Water
# 470  111  Water
# 541   90  Water
# 548  100  Water
# 562   95  Water
# 597  105  Water
# 654  100  Water
# 655  165  Water
# 713   91  Water
# 714   91  Water

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].value_counts(normalize=True)
# Out:
# Water       0.14000
# Normal      0.12250
# Grass       0.08750
# Bug         0.08625
# Psychic     0.07125
# Fire        0.06500
# Rock        0.05500
# Electric    0.05500
# Dragon      0.04000
# Ghost       0.04000
# Ground      0.04000
# Dark        0.03875
# Poison      0.03500
# Fighting    0.03375
# Steel       0.03375
# Ice         0.03000
# Fairy       0.02125
# Flying      0.00500
# Name: Type 1, dtype: float64

# %%
df['Type 1'].value_counts().plot.bar()
plt.show()

# %%
df['Type 1'].value_counts(normalize=True).plot.bar()
plt.show()

# %% [markdown]
# ##### loc and iloc

# %%
df.loc[:, 'Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.loc[1:5, 'Type 1']
# Out:
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# 5     Fire
# Name: Type 1, dtype: object

# %%
df.loc[:, 'Type 1': 'HP']
# Out:
#       Type 1  Type 2  Total  HP
# 0      Grass  Poison    318  45
# 1      Grass  Poison    405  60
# 2      Grass  Poison    525  80
# 3      Grass  Poison    625  80
# 4       Fire  Flying    309  39
# ..       ...     ...    ...  ..
# 795     Rock   Fairy    600  50
# 796     Rock   Fairy    700  50
# 797  Psychic   Ghost    600  80
# 798  Psychic    Dark    680  80
# 799     Fire   Water    600  80
#
# [800 rows x 4 columns]

# %%
df.loc[1:5, 'Type 1': 'HP']
# Out:
#   Type 1  Type 2  Total  HP
# 1  Grass  Poison    405  60
# 2  Grass  Poison    525  80
# 3  Grass  Poison    625  80
# 4   Fire  Flying    309  39
# 5   Fire  Flying    405  58

# %%
df.loc[[1, 27, 13], 'Type 1': 'HP']
# Out:
#     Type 1  Type 2  Total  HP
# 1    Grass  Poison    405  60
# 27  Normal  Flying    442  65
# 13     Bug  Flying    195  45

# %%
df.loc[[1, 27, 13], ['Type 1', 'HP']]
# Out:
#     Type 1  HP
# 1    Grass  60
# 27  Normal  65
# 13     Bug  45

# %%
df.iloc[:, 2]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.iloc[1:5, 2:5]
# Out:
#   Type 1  Type 2  Total
# 1  Grass  Poison    405
# 2  Grass  Poison    525
# 3  Grass  Poison    625
# 4   Fire  Flying    309

# %%
df.iloc[[13, 27], 2]
# Out:
# 13       Bug
# 27    Normal
# Name: Type 1, dtype: object

# %%
df.HP.iloc[1]
# Out:
# 60

# %%
df['HP']>80
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: HP, Length: 800, dtype: bool

# %%
df[df['HP']>80]['HP']
# Out:
# 22      83
# 23      83
# 36      90
# 39      81
# 41      95
#       ...
# 789     95
# 791     85
# 792    126
# 793    126
# 794    108
# Name: HP, Length: 193, dtype: int64

# %%
df[df['HP']>80]['HP']=80
# Out:
# <ipython-input-60-9e217dc3d731>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['HP']>80]['HP']=80

# %%
df[df['HP']>80]['HP']
# Out:
# 22      83
# 23      83
# 36      90
# 39      81
# 41      95
#       ...
# 789     95
# 791     85
# 792    126
# 793    126
# 794    108
# Name: HP, Length: 193, dtype: int64

# %%
df.loc[(df['HP']>80), :]
# Out:
#      Number              Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 22       18           Pidgeot  Normal  Flying    479   83      80       75
# 23       18      Mega Pidgeot  Normal  Flying    579   83      80       80
# 36       31         Nidoqueen  Poison  Ground    505   90      92       87
# 39       34          Nidoking  Poison  Ground    505   81     102       77
# 41       36          Clefable   Fairy  Flying    483   95      70       73
# ..      ...               ...     ...     ...    ...  ...     ...      ...
# 789     713           Avalugg     Ice  Flying    514   95     117      184
# 791     715           Noivern  Flying  Dragon    535   85      70       80
# 792     716           Xerneas   Fairy  Flying    680  126     131       95
# 793     717           Yveltal    Dark  Flying    680  126     131       95
# 794     718  Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[(df['HP']>80), 'HP']
# Out:
# 22      83
# 23      83
# 36      90
# 39      81
# 41      95
#       ...
# 789     95
# 791     85
# 792    126
# 793    126
# 794    108
# Name: HP, Length: 193, dtype: int64

# %%
df.loc[(df['HP']>80), 'HP']=80

# %%
df[df['HP']>80]
# Out:
# Empty DataFrame
# Columns: [Number, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df[df['Type 1'].isin(['Grass', 'Fire'])]
# Out:
#      Number           Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1      Bulbasaur  Grass  Poison    318  45      49       49
# 1         2        Ivysaur  Grass  Poison    405  60      62       63
# 2         3       Venusaur  Grass  Poison    525  80      82       83
# 3         3  Mega Venusaur  Grass  Poison    625  80     100      123
# 4         4     Charmander   Fire  Flying    309  39      52       43
# ..      ...            ...    ...     ...    ...  ..     ...      ...
# 735     667         Litleo   Fire  Normal    369  62      50       58
# 736     668         Pyroar   Fire  Normal    507  80      68       72
# 740     672         Skiddo  Grass  Flying    350  66      65       48
# 741     673         Gogoat  Grass  Flying    531  80     100       62
# 799     721      Volcanion   Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1          0
# ...

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %% [markdown]
# ##### Like Operations in Pandas

# %%
df.Name.str.contains("aur")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
df[df.Name.str.contains("aur")]
# Out:
#      Number           Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1      Bulbasaur   Grass  Poison    318  45      49       49
# 1         2        Ivysaur   Grass  Poison    405  60      62       63
# 2         3       Venusaur   Grass  Poison    525  80      82       83
# 3         3  Mega Venusaur   Grass  Poison    625  80     100      123
# 138     128         Tauros  Normal  Flying    490  75     100       95
# 768     698         Amaura    Rock     Ice    362  77      59       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1          0
# 1         80       80     60           1          0
# 2        100      100     80           1          0
# 3        122      120     80           1          0
# 138       40       70    110           1          0
# 768       67       63     46           6          0

# %%
df.set_index('Number')
# Out:
#                        Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# Number
# 1                 Bulbasaur    Grass  Poison    318  45      49       49
# 2                   Ivysaur    Grass  Poison    405  60      62       63
# 3                  Venusaur    Grass  Poison    525  80      82       83
# 3             Mega Venusaur    Grass  Poison    625  80     100      123
# 4                Charmander     Fire  Flying    309  39      52       43
# ...                     ...      ...     ...    ...  ..     ...      ...
# 719                 Diancie     Rock   Fairy    600  50     100      150
# 719            Mega Diancie     Rock   Fairy    700  50     160      110
# 720     HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720      HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721               Volcanion     Fire   Water    600  80     110      120
#
#         Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Number
# ...

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df.set_index('Number', inplace=True)

# %%
df.head()
# Out:
#                  Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Number
# 1           Bulbasaur  Grass  Poison    318  45      49       49       65
# 2             Ivysaur  Grass  Poison    405  60      62       63       80
# 3            Venusaur  Grass  Poison    525  80      82       83      100
# 3       Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4          Charmander   Fire  Flying    309  39      52       43       60
#
#         Sp. Def  Speed  Generation  Legendary
# Number
# 1            65     45           1          0
# 2            80     60           1          0
# 3           100     80           1          0
# 3           120     80           1          0
# 4            50     65           1          0

# %%
df.reset_index()
# Out:
#      Number                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1            Bulbasaur    Grass  Poison    318  45      49       49
# 1         2              Ivysaur    Grass  Poison    405  60      62       63
# 2         3             Venusaur    Grass  Poison    525  80      82       83
# 3         3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4         4           Charmander     Fire  Flying    309  39      52       43
# ..      ...                  ...      ...     ...    ...  ..     ...      ...
# 795     719              Diancie     Rock   Fairy    600  50     100      150
# 796     719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797     720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799     721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#                  Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Number
# 1           Bulbasaur  Grass  Poison    318  45      49       49       65
# 2             Ivysaur  Grass  Poison    405  60      62       63       80
# 3            Venusaur  Grass  Poison    525  80      82       83      100
# 3       Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4          Charmander   Fire  Flying    309  39      52       43       60
#
#         Sp. Def  Speed  Generation  Legendary
# Number
# 1            65     45           1          0
# 2            80     60           1          0
# 3           100     80           1          0
# 3           120     80           1          0
# 4            50     65           1          0

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
print(df['HP'].max())
print(df['HP'].min())
print(df['HP'].sum())
print(df['HP'].std())
print(df['HP'].var())
# Out:
# 80
# 1
# 50958
# 15.588609613660493
# 243.00474968710836

# %%
df['HP'].idxmax()
# Out:
# 2

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %% [markdown]
# ##### GroupBy method

# %%
df.groupby('Legendary')['HP'].mean()
# Out:
# Legendary
# 0    62.533333
# 1    76.861538
# Name: HP, dtype: float64

# %%
df.groupby('Legendary')[['Attack', 'Defense']].mean()
# Out:
#                Attack    Defense
# Legendary
# 0           75.669388  71.559184
# 1          116.676923  99.661538

# %%
df.groupby('Legendary')[['Attack', 'Defense']].agg(['max', 'min'])
# Out:
#           Attack     Defense
#              max min     max min
# Legendary
# 0            185   5     230   5
# 1            190  50     200  20

# %%
df.groupby('Legendary')[['Attack', 'Defense']].agg(['max', min])
# Out:
#           Attack     Defense
#              max min     max min
# Legendary
# 0            185   5     230   5
# 1            190  50     200  20

# %%
df.groupby('Legendary')[['Attack', 'Defense']].agg({'Attack':'max', 'Defense':'min'})
# Out:
#            Attack  Defense
# Legendary
# 0             185        5
# 1             190       20

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df.sort_values('HP')
# Out:
#      Number         Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 316     292     Shedinja      Bug    Ghost    236   1      90       45
# 55       50      Diglett   Ground   Flying    265  10      55       25
# 139     129     Magikarp    Water   Flying    200  20      10       55
# 230     213      Shuckle      Bug     Rock    505  20      10      230
# 487     439     Mime Jr.  Psychic    Fairy    310  20      25       45
# ..      ...          ...      ...      ...    ...  ..     ...      ...
# 420     381  Mega Latios   Dragon  Psychic    700  80     130      100
# 419     381       Latios   Dragon  Psychic    600  80      90       80
# 418     380  Mega Latias   Dragon  Psychic    700  80     100      120
# 416     379    Registeel    Steel   Flying    580  80      75      150
# 799     721    Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 316       30       30     40           3          0
# ...

# %%
df.sort_values('HP', ascending=True)
# Out:
#      Number         Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 316     292     Shedinja      Bug    Ghost    236   1      90       45
# 55       50      Diglett   Ground   Flying    265  10      55       25
# 139     129     Magikarp    Water   Flying    200  20      10       55
# 230     213      Shuckle      Bug     Rock    505  20      10      230
# 487     439     Mime Jr.  Psychic    Fairy    310  20      25       45
# ..      ...          ...      ...      ...    ...  ..     ...      ...
# 420     381  Mega Latios   Dragon  Psychic    700  80     130      100
# 419     381       Latios   Dragon  Psychic    600  80      90       80
# 418     380  Mega Latias   Dragon  Psychic    700  80     100      120
# 416     379    Registeel    Steel   Flying    580  80      75      150
# 799     721    Volcanion     Fire    Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 316       30       30     40           3          0
# ...

# %%
df.sort_values('HP', ascending=False)
# Out:
#      Number                   Name   Type 1   Type 2  Total  HP  Attack  \
# 400     365                Walrein      Ice    Water    530  80      80
# 424     383  GroudonPrimal Groudon   Ground     Fire    770  80     180
# 422     382    KyogrePrimal Kyogre    Water   Flying    770  80     150
# 421     382                 Kyogre    Water   Flying    670  80     100
# 420     381            Mega Latios   Dragon  Psychic    700  80     130
# ..      ...                    ...      ...      ...    ...  ..     ...
# 381     349                 Feebas    Water   Flying    200  20      15
# 487     439               Mime Jr.  Psychic    Fairy    310  20      25
# 230     213                Shuckle      Bug     Rock    505  20      10
# 55       50                Diglett   Ground   Flying    265  10      55
# 316     292               Shedinja      Bug    Ghost    236   1      90
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['HP', 'Attack'], ascending=[True, False])
# Out:
#      Number                Name    Type 1   Type 2  Total  HP  Attack  \
# 316     292            Shedinja       Bug    Ghost    236   1      90
# 55       50             Diglett    Ground   Flying    265  10      55
# 186     172               Pichu  Electric   Flying    205  20      40
# 388     355             Duskull     Ghost   Flying    295  20      40
# 487     439            Mime Jr.   Psychic    Fairy    310  20      25
# ..      ...                 ...       ...      ...    ...  ..     ...
# 616     555  DarmanitanZen Mode      Fire  Psychic    540  80      30
# 394     360              Wynaut   Psychic   Flying    260  80      23
# 261     242             Blissey    Normal   Flying    540  80      10
# 121     113             Chansey    Normal   Flying    450  80       5
# 488     440             Happiny    Normal   Flying    220  80       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 316       45       30       30     40           3          0
# ...

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
pd.cut(df['HP'], 5)
# Out:
# 0      (32.6, 48.4]
# 1      (48.4, 64.2]
# 2      (64.2, 80.0]
# 3      (64.2, 80.0]
# 4      (32.6, 48.4]
#            ...
# 795    (48.4, 64.2]
# 796    (48.4, 64.2]
# 797    (64.2, 80.0]
# 798    (64.2, 80.0]
# 799    (64.2, 80.0]
# Name: HP, Length: 800, dtype: category
# Categories (5, interval[float64]): [(0.921, 16.8] < (16.8, 32.6] < (32.6, 48.4] < (48.4, 64.2] < (64.2, 80.0]]

# %%
pd.cut(df['HP'], 5).value_counts()
# Out:
# (64.2, 80.0]     441
# (48.4, 64.2]     214
# (32.6, 48.4]     120
# (16.8, 32.6]      23
# (0.921, 16.8]      2
# Name: HP, dtype: int64

# %%
df['HP_cut']=pd.cut(df['HP'], 5)

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary        HP_cut
# 0       65     45           1          0  (32.6, 48.4]
# 1       80     60           1          0  (48.4, 64.2]
# 2      100     80           1          0  (64.2, 80.0]
# 3      120     80           1          0  (64.2, 80.0]
# 4       50     65           1          0  (32.6, 48.4]

# %% [markdown]
# ##### Delete Column in DataFrame

# %%
df.drop('HP_cut', axis=1)
# Out:
#      Number                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1            Bulbasaur    Grass  Poison    318  45      49       49
# 1         2              Ivysaur    Grass  Poison    405  60      62       63
# 2         3             Venusaur    Grass  Poison    525  80      82       83
# 3         3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4         4           Charmander     Fire  Flying    309  39      52       43
# ..      ...                  ...      ...     ...    ...  ..     ...      ...
# 795     719              Diancie     Rock   Fairy    600  50     100      150
# 796     719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797     720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799     721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary        HP_cut
# 0       65     45           1          0  (32.6, 48.4]
# 1       80     60           1          0  (48.4, 64.2]
# 2      100     80           1          0  (64.2, 80.0]
# 3      120     80           1          0  (64.2, 80.0]
# 4       50     65           1          0  (32.6, 48.4]

# %%
df.drop('HP_cut', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %% [markdown]
# ##### Delete rows in DataFrame

# %%
df.drop([1, 5])
#df.drop([1, 5], inplace=True)
# Out:
#      Number                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0         1            Bulbasaur    Grass  Poison    318  45      49       49
# 2         3             Venusaur    Grass  Poison    525  80      82       83
# 3         3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4         4           Charmander     Fire  Flying    309  39      52       43
# 6         6            Charizard     Fire  Flying    534  78      84       78
# ..      ...                  ...      ...     ...    ...  ..     ...      ...
# 795     719              Diancie     Rock   Fairy    600  50     100      150
# 796     719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797     720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799     721            Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df._get_numeric_data()
# Out:
#      Number  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0         1    318  45      49       49       65       65     45           1
# 1         2    405  60      62       63       80       80     60           1
# 2         3    525  80      82       83      100      100     80           1
# 3         3    625  80     100      123      122      120     80           1
# 4         4    309  39      52       43       60       50     65           1
# ..      ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795     719    600  50     100      150      100      150     50           6
# 796     719    700  50     160      110      160      110    110           6
# 797     720    600  80     110       60      150      130     70           6
# 798     720    680  80     160       60      170      130     80           6
# 799     721    600  80     110      120      130       90     70           6
#
#      Legendary
# 0            0
# ...

# %%
num_cols=df._get_numeric_data().columns
print(num_cols)
# Out:
# Index(['Number', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
#        'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.select_dtypes(include=['object'])
# Out:
#                     Name   Type 1  Type 2
# 0              Bulbasaur    Grass  Poison
# 1                Ivysaur    Grass  Poison
# 2               Venusaur    Grass  Poison
# 3          Mega Venusaur    Grass  Poison
# 4             Charmander     Fire  Flying
# ..                   ...      ...     ...
# 795              Diancie     Rock   Fairy
# 796         Mega Diancie     Rock   Fairy
# 797  HoopaHoopa Confined  Psychic   Ghost
# 798   HoopaHoopa Unbound  Psychic    Dark
# 799            Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
cat_cols=list(set(df.columns)-set(num_cols))

print(cat_cols)
# Out:
# ['Type 2', 'Name', 'Type 1']

# %% [markdown]
# ##### Apply function on Dataframe

# %%
df[num_cols].apply(np.max)
# Out:
# Number        721
# Total         780
# HP             80
# Attack        190
# Defense       230
# Sp. Atk       194
# Sp. Def       230
# Speed         180
# Generation      6
# Legendary       1
# dtype: int64

# %%
df.head()
# Out:
#    Number           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1       2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2       3       Venusaur  Grass  Poison    525  80      82       83      100
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4       4     Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0
